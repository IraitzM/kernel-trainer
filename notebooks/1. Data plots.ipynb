# %%
from kernel_trainer.dataset import DataGenerator

samples = 5000
imbalance_ratio = 0.5
seed=4321

generator = DataGenerator(
    samples=samples, imbalance_ratio=imbalance_ratio, seed=seed
)

data = generator.generate_dataset('0')

# %%
from kernel_trainer.utils import visualize_3d

visualize_3d(data)

# %%
data = generator.generate_dataset('1a')
visualize_3d(data)

# %%
data = generator.generate_dataset('1b')
visualize_3d(data)

# %%
data = generator.generate_dataset('1c')
visualize_3d(data)

# %%
data = generator.generate_dataset('2a')
visualize_3d(data)

# %%
data = generator.generate_dataset('2b')
visualize_3d(data)

# %%
data = generator.generate_dataset('2c')
visualize_3d(data)

# %%
generator = DataGenerator(
    samples=samples, imbalance_ratio=0.1, seed=seed
)

data = generator.generate_dataset('3a')
visualize_3d(data)

# %%
data = generator.generate_dataset('3b')
visualize_3d(data)

# %%
data = generator.generate_dataset('3c')
visualize_3d(data)

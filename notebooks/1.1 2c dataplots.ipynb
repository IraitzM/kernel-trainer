# %%
from kernel_trainer.dataset import DataGenerator

samples = 5000
imbalance_ratio = 0.5
seed = 4321

generator = DataGenerator(samples=samples, imbalance_ratio=imbalance_ratio, seed=seed)

data = generator.generate_dataset("2c")

# %%
from kernel_trainer.utils import visualize_3d

visualize_3d(data)
